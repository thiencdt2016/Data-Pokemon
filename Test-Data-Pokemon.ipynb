# %%
import pandas as pd

# %%
df = pd.read_csv("Pokemon.csv")

# %%
df.head(50).style.bar(subset=['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'])
# Out:
# <style  type="text/css" >
#     #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.0%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.6%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 22.3%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.2%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row0_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 34.7%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row0_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 45.0%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row0_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 47.8%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 27.3%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.3%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 41.7%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row1_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 45.1%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row1_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 60.0%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row1_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.0%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 75.2%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 45.5%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 47.7%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 61.2%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row2_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 59.0%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row2_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 80.0%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row2_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.0%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 97.9%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 45.5%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 61.5%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row3_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 74.3%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row3_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row3_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.0%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.0%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.2%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row4_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 24.6%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row4_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 22.3%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row4_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.2%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row4_col9 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 30.0%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row4_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.0%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 47.8%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row5_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.5%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row5_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.8%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row5_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.9%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row5_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 45.1%, transparent 0%);
#         }    #T_a62b5ef0_8fe9_11e9_acb6_00266c1d1654row5_col9 {
#             width:  10em;
#              height:  80%;
#             backgrou

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# 50%     70.000000   65.000000     3.00000
# 75%     90.000000   90.000000     5.00000
# max    230.000000  180.000000     6.00000

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
from pandas.tools import plotting

# %%
plotting.scatter_matrix(df.iloc[:, 4:11], figsize=(8,8))
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0F7899E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0F7FDC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0F869E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0F89A128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0F8BF390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0F8E35F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0F909860>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0F930B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0F930B38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0F95B9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0F983F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0F9AE4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0F9D3A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0F9F6F98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FA24550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FA48AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FA75080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FA9A748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FABFB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FAEC128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FB136A0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FB3BC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FB6B1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FB94748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FBB9CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FBEA278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FC117F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FC37D68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FC6A320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FC90898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FCBAE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FCEA3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FD10940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FD38EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FD67470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FD8E9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FDB8F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FDE8518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FE0FA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FE3F048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FE665C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FE8DB38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FEBD0F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FEE7668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FF0FBE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FF40198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FF64710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FF8DC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF0FFBD240>]],
#       dtype=object)

# %%
plt.show()

# %%
type1 = list(set(list(df['Type 1'])))

# %%
print(len(type1), type1)
# Out:
# 18 ['Water', 'Grass', 'Poison', 'Rock', 'Ice', 'Steel', 'Bug', 'Ground', 'Fairy', 'Fighting', 'Psychic', 'Dragon', 'Fire', 'Ghost', 'Flying', 'Normal', 'Dark', 'Electric']

# %%
cmap = plt.get_cmap('coolwarm')

# %%
colors = [cmap((type1.index(c) + 1) / (len(type1) + 2)) for c in df['Type 1'].tolist()]

# %%
plotting.scatter_matrix(df.iloc[:, 4:11], figsize=(8,8), color=colors, alpha = 0.5)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AA11A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF189C43C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AAA9A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AABEC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1983E048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF198585C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF19871B38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF19890128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF19890160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF198C3BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF198E4198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF198FB710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF19916C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF199371D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF19951748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AACACC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AAEC278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AB057F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AB1ED68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AB403C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AB59940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AB73F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AB94390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1ABAD908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1ABC8E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1ABE7438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AC039B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AC24F28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AC4F4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AC73A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AC98FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1ACC3588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1ACE7B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AD150B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AD3B630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AD61BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AD91160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1ADB76D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1ADDFC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AE10208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AE36780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AE5FCF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AE8F2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AEB6828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AEDEDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AF10358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AF368D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AF5EE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1AF90400>]],
#       dtype=object)

# %%
from matplotlib.colors import LinearSegmentedColormap

# %%
dic = {'red':   ((0,0,0), (0.5,1,1),(1,1,1)),
       'green': ((0,0,0),(0.5,1,1) ,(1,0,0)),
       'blue':  ((0,1,1), (0.5,0,0),(1,0,0))
       }

# %%
tricolor_cmap = LinearSegmentedColormap('tricolor', dic)

# %%
cmap = tricolor_cmap

# %%
colors = [cmap((type1.index(c) + 1) / (len(type1) + 2)) for c in df['Type 1'].tolist()]

# %%
plotting.scatter_matrix(df.iloc[:, 4:11], figsize=(8,8), color = colors)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1B8F4BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1B8FC160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1BD78DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1B7B30F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1B8ED1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1B6F79E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1A973CF8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1B7D1940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1B7D1978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C04D438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C0A79B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1BD29F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1B8CE4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1BC45A58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1BD5FFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1B7FE588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1B835B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1BB900B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1B788630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C3E1BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C3E3160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1BFE36D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1BFEDC50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C028208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C014780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C435CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C41D2B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1BF32828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1BF6BDA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1BF62358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1BFA88D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C1C9E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C1F6400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C21A978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C23FEF0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C26C4A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C292A20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C2B6F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C2E3550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C309AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C337080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C35A5F8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C37CB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1C3AD128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1D4306A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1D455C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1D4841D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1D4A7748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BF1D4CCCC0>]],
#       dtype=object)

# %%
import numpy as np

# %%
pd.DataFrame(np.corrcoef(df.iloc[:, 4:11].T.values.tolist()), columns = df.iloc[:, 4:11].columns, index = df.iloc[:, 4:11].columns)
# Out:
#             Total        HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# Total    1.000000  0.618748  0.736211  0.612787  0.747250  0.717609  0.575943
# HP       0.618748  1.000000  0.422386  0.239622  0.362380  0.378718  0.175952
# Attack   0.736211  0.422386  1.000000  0.438687  0.396362  0.263990  0.381240
# Defense  0.612787  0.239622  0.438687  1.000000  0.223549  0.510747  0.015227
# Sp. Atk  0.747250  0.362380  0.396362  0.223549  1.000000  0.506121  0.473018
# Sp. Def  0.717609  0.378718  0.263990  0.510747  0.506121  1.000000  0.259133
# Speed    0.575943  0.175952  0.381240  0.015227  0.473018  0.259133  1.000000

# %%
corrcoef = np.corrcoef(df.iloc[:, 4:11].T.values.tolist())

# %%
plt.imshow(corrcoef, interpolation='nearest', cmap=plt.cm.coolwarm)

# %%
tick_marks = np.arange(len(corrcoef))

# %%
plt.xticks(tick_marks, df.iloc[:, 4:11].columns, rotation=60)
# Out:
# ([<matplotlib.axis.XTick at 0x1bf23bac4a8>,
#   <matplotlib.axis.XTick at 0x1bf23bdb518>,
#   <matplotlib.axis.XTick at 0x1bf23bdba20>,
#   <matplotlib.axis.XTick at 0x1bf23ba3198>,
#   <matplotlib.axis.XTick at 0x1bf23ba3630>,
#   <matplotlib.axis.XTick at 0x1bf23ba3b00>,
#   <matplotlib.axis.XTick at 0x1bf23ba3d30>],
#  <a list of 7 Text xticklabel objects>)

# %%
plt.yticks(tick_marks, df.iloc[:, 4:11].columns)
# Out:
# ([<matplotlib.axis.YTick at 0x1bf238429e8>,
#   <matplotlib.axis.YTick at 0x1bf23842320>,
#   <matplotlib.axis.YTick at 0x1bf23ba3ac8>,
#   <matplotlib.axis.YTick at 0x1bf238499e8>,
#   <matplotlib.axis.YTick at 0x1bf23849eb8>,
#   <matplotlib.axis.YTick at 0x1bf23849ac8>,
#   <matplotlib.axis.YTick at 0x1bf238535f8>],
#  <a list of 7 Text yticklabel objects>)

# %%
plt.tight_layout()

# %%
corrcoef = np.corrcoef(df.iloc[:, 4:11].T.values.tolist())
plt.imshow(corrcoef, interpolation='nearest', cmap=plt.cm.coolwarm)
plt.colorbar(label='Correlation Coefficient')
tick_marks = np.arange(len(corrcoef))
plt.xticks(tick_marks, df.iloc[:, 4:11].columns, rotation=90)
plt.yticks(tick_marks, df.iloc[:, 4:11].columns)
plt.tight_layout()

# %%
#バイオリンポロット
fig = plt.figure()
ax = fig.add_subplot(111)
ax.violinplot(df.iloc[:, 4:11].values.T.tolist())
ax.set_xticks([1,2,3,4,5,6,7])
ax.set_xticklabels(df.columns[4:11], rotation=90)
plt.grid()
plt.show()

# %%
for index, type1s in enumerate(type1):
    df2 = df[df['Type 1'] == type1s]
    fig = plt.figure(figsize=(8,4))
    ax = fig.add_subplot(1,1,1)
    plt.title(type1s)
    ax.set_ylim([0, 260])
    ax.violinplot(df2.iloc[:, 5:11].values.T.tolist())
    ax.set_xticks([1,2,3,4,5,6])
    ax.set_xticklabels(df2.columns[5:11], rotation=90)
    plt.grid()
    plt.show()
